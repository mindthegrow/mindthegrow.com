# %%
import urllib.request
import IPython.display as display

# %%
search_term = 'organic-farm'
image_size = ''
url = 'https://source.unsplash.com/random/'+image_size+'?'+search_term
image_name = 'test.jpg'
urllib.request.urlretrieve(url, image_name)
# Out:
# ('test.jpg', <http.client.HTTPMessage at 0x7feef80da278>)

# %% [markdown]
# # Preview Image

# %%
display.Image(image_name)

# %% [markdown]
# # See file size

# %%
# !ls -lh $image_name
# Out:
# -rw-r--r-- 1 mathematicalmichael mathematicalmichael 170K Jun 29 17:22 test.jpg

# %%
new_name = search_term+'.jpg'
# !convert -resize 800x $image_name img/solutions/$new_name
new_name = new_name.replace('.jpg', '-full.jpg')
# !mv $image_name img/$new_name

# %%
display.Image('img/'+new_name)

# %%
# !ls -lh img/sustainability-full.jpg
# Out:
# -rw-r--r-- 1 mathematicalmichael mathematicalmichael 83K Jun 29 17:08 img/sustainability-full.jpg

# %%
# !ls -lh img/solutions/sustainability.jpg
# Out:
# -rw-r--r-- 1 mathematicalmichael mathematicalmichael 31K Jun 29 17:14 img/solutions/sustainability.jpg
