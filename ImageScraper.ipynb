# %%
import urllib.request
import IPython.display as display

# %%
search_term = 'coffee-plantation'
image_size = ''
url = 'https://source.unsplash.com/random/'+image_size+'?'+search_term
image_name = 'test.jpg'
urllib.request.urlretrieve(url, image_name)
# Out:
# ('test.jpg', <http.client.HTTPMessage at 0x7ff3e4f6c828>)

# %% [markdown]
# # Preview Image

# %%
display.Image(image_name)

# %% [markdown]
# # See file size

# %%
# !ls -lh $image_name
# Out:
# total 2.2M
# -rw-r--r-- 1 mathematicalmichael mathematicalmichael  22K Jun 29 12:52 android-chrome-192x192.png
# -rw-r--r-- 1 mathematicalmichael mathematicalmichael  69K Jun 29 12:52 android-chrome-512x512.png
# -rw-r--r-- 1 mathematicalmichael mathematicalmichael  17K Jun 29 12:52 apple-touch-icon.png
# -rw-r--r-- 1 mathematicalmichael mathematicalmichael  246 Jun 29 12:52 browserconfig.xml
# -rw-r--r-- 1 mathematicalmichael mathematicalmichael  24K Jun 29 12:52 elements.html
# -rw-r--r-- 1 mathematicalmichael mathematicalmichael 1.5K Jun 29 12:52 favicon-16x16.png
# -rw-r--r-- 1 mathematicalmichael mathematicalmichael 2.3K Jun 29 12:52 favicon-32x32.png
# -rw-r--r-- 1 mathematicalmichael mathematicalmichael  15K Jun 29 12:52 favicon.ico
# -rw-r--r-- 1 mathematicalmichael mathematicalmichael 1.1M Jul  2 18:59 ImageScraper.ipynb
# drwxr-xr-x 5 mathematicalmichael mathematicalmichael  32K Jun 30 15:45 img
# ...

# %%
new_name = search_term+'.jpg'
# !convert -resize 800x $image_name img/solutions/$new_name
new_name = new_name.replace('.jpg', '-full.jpg')
# !mv $image_name img/$new_name

# %%
display.Image('img/'+image_name)

# %%
# !ls -lh img/sustainability-full.jpg

# %%
# !ls -lh img/solutions/sustainability.jpg

# %%
# !ls -lh ../static/img/banner.jpg

# %%
# !convert img/solutions/mj.jpg -resize 1280x -crop 1280x900++ mj.jpg

# %%
# !pwd
# Out:
# /media/mathematicalmichael/HANK/repos/mtg/static
