# %%
import urllib.request
import IPython.display as display

# %%
search_term = 'farm'
image_size = '1800x1200'
url = 'https://source.unsplash.com/random/'+image_size+'?'+search_term
image_name = 'img/banner-full.jpg'
urllib.request.urlretrieve(url, image_name)
# Out:
# ('img/banner-full.jpg', <http.client.HTTPMessage at 0x7feef81140b8>)

# %% [markdown]
# # Preview Image

# %%
display.Image(image_name)

# %% [markdown]
# # See file size

# %%
# !ls -lh $image_name
# Out:
# -rw-r--r-- 1 mathematicalmichael mathematicalmichael 379K Jun 29 14:45 img/banner-full.jpg

# %%
# two languages in the same cell!
# !echo $image_name
print(image_name)
# Out:
# img/banner-full.jpg
# img/banner-full.jpg

# %%
# !convert -resize 800x $image_name img/farm.jpg

# %%
display.Image('img/farm.jpg')

# %%
# !ls -lh img/
# Out:
# total 928K
# -rw-r--r-- 1 mathematicalmichael mathematicalmichael 379K Jun 29 14:45 banner-full.jpg
# -rw-r--r-- 1 mathematicalmichael mathematicalmichael 176K Jun 29 14:19 banner.jpg
# drwxr-xr-x 2 mathematicalmichael mathematicalmichael  32K Jun 29 12:52 cce
# -rw-r--r-- 1 mathematicalmichael mathematicalmichael  72K Jun 29 14:45 farm.jpg
# -rw-r--r-- 1 mathematicalmichael mathematicalmichael  15K Jun 29 12:52 grow-logo.png
# -rw-r--r-- 1 mathematicalmichael mathematicalmichael  13K Jun 29 12:52 grow.png
# -rw-r--r-- 1 mathematicalmichael mathematicalmichael  88K Jun 29 12:52 logo-full.png
# -rw-r--r-- 1 mathematicalmichael mathematicalmichael 9.4K Jun 29 12:52 logo.png
# drwxr-xr-x 2 mathematicalmichael mathematicalmichael  32K Jun 29 12:52 services
